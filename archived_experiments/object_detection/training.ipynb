# %%
# !git clone https://github.com/WongKinYiu/yolov7
# %cd yolov7
# !pip install -r requirements.txt

# %% [markdown]
# <h2>Getting Dataset from Roboflow</h2>

# %%
# !pip install roboflow
# %cd yolov7
# # Training Sim
# from roboflow import Roboflow
# rf = Roboflow(api_key="CHhwyY9fW3TOXoTlxN1i")
# project = rf.workspace("monash-university-gcbz8").project("fruits_gazebo")
# dataset = project.version(2).download("yolov7")

# Training Real
from roboflow import Roboflow
rf = Roboflow(api_key="Px3Khg5RNzeS0ESmmqJ5")
project = rf.workspace("school-vdxga").project("pipe_detection-xmkqn")
dataset = project.version(2).download("yolov7")
# Out:
# [WinError 2] The system cannot find the file specified: 'yolov7'
# d:\School\pipe-recognisation\object_detection\yolov7
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to pipe_detection-2 in yolov7pytorch:: 100%|██████████| 502/502 [00:00<00:00, 973.43it/s]

# %%
dataset.location
# Out:
# 'd:\\School\\pipe-recognisation\\object_detection\\yolov7\\pipe_detection-2'

# %% [markdown]
# <h2>Downloading Model</h2>

# %%
# Now go to "https://github.com/WongKinYiu/yolov7/releases/ and download yolov7.pt

# %% [markdown]
# <h2> Training </h2>

# %%
import os
import sys

if os.path.exists('best.pt'): # check if you manually upload a path to yolov7
  weight_path = 'best.pt'
elif os.path.exists("runs/train/'real'/weights/best.pt"): # check if a best path from previous training exist else use the default
  weight_path = "runs/train/'real'/weights/best.pt"
else: # use the default weight
  weight_path = 'yolov7.pt'
print('using weight_path:', weight_path)
# Out:
# using weight_path: yolov7.pt

# %%
# !python train.py --workers 2 --batch 10 --cfg cfg/training/yolov7.yaml --epochs 200 --data {dataset.location}/data.yaml --weights weight_path --device 0 --name model --exist-ok
# Out:
# wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)
# YOLOR  f378fd4 torch 1.11.0+cu113 CUDA:0 (NVIDIA GeForce RTX 3070, 8191.5MB)
#
# Namespace(weights='weight_path', cfg='cfg/training/yolov7.yaml', data='d:\\School\\pipe-recognisation\\object_detection\\yolov7\\pipe_detection-2/data.yaml', hyp='data/hyp.scratch.p5.yaml', epochs=200, batch_size=10, img_size=[640, 640], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=2, project='runs/train', entity=None, name='model', exist_ok=True, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], world_size=1, global_rank=-1, save_dir='runs\\train\\model', total_batch_size=10)
# ...

# %%
# !python detect.py --weights best.pt --conf 0.3 --source {dataset.location}/valid/images
# Out:
# Namespace(weights=['best.pt'], source='d:\\School\\2022_S2\\ECE4078\\Project\\yolov7_fruits\\yolov7\\YOLOv7_fruits-7/valid/images', img_size=640, conf_thres=0.3, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# 1 apple, 1 lemon, 1 strawberry, Done. (14.5ms) Inference, (106.8ms) NMS
#  The image with the result is saved in: runs\detect\exp4\0_0resized_52_png.rf.bfbcfb9007d231003d320a0c4ff60a83.jpg
# 1 apple, 1 lemon, 1 strawberry, Done. (13.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\exp4\0_0resized_72_png.rf.aab4e1403dd939d3396e5c1b98e3d6f6.jpg
# ...
