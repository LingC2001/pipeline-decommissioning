# %%
import torch
import torchvision
import cv2

# %%
import os
import numpy as np
import json
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# pip install 'git+https://github.com/facebookresearch/detectron2.git'
import sys
sys.path.append("detectron2-main/")
from detectron2.structures import BoxMode
from detectron2.data import DatasetCatalog, MetadataCatalog
from detectron2.utils.logger import setup_logger
from detectron2.data.datasets import register_coco_instances

from detectron2 import model_zoo
from detectron2.engine import DefaultTrainer, DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import ColorMode, Visualizer

from detectron2.utils.visualizer import Visualizer
from detectron2.utils.visualizer import ColorMode
import cv2
import pickle

# %%
#### Utils ####
def plot_samples(dataset_name, n=1):
    dataset_custom = DatasetCatalog.get(dataset_name)
    dataset_custom_metadata = MetadataCatalog.get(dataset_name)

    for s in random.sample(dataset_custom, n):
        img = cv2.imread(s["file_name"])
        v = Visualizer(img[:,:,::-1], metadata=dataset_custom_metadata, scale = 1)
        v = v.draw_dataset_dict(s)
        plt.figure(figsize=(5,5))
        plt.imshow(v.get_image())
        plt.show()

def get_train_cfg(config_file_path, checkpoint_url, train_dataset_name, test_dataset_name, num_classes, device, output_dir):
    cfg = get_cfg()
    cfg.merge_from_file(model_zoo.get_config_file(config_file_path))
    cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url(checkpoint_url)
    cfg.DATASETS.TRAIN = (train_dataset_name,)
    cfg.DATASETS.TEST = (test_dataset_name,)
    cfg.DATALOADER.NUM_WORKERS = 2
    cfg.SOLVER.IMS_PER_BATCH = 5
    cfg.SOLVER.BASE_LR = 0.00025
    cfg.SOLVER.MAX_ITER = 10000
    cfg.SOLVER.STEPS = []
    cfg.MODEL.ROI_HEADS.NUM_CLASSES = num_classes
    cfg.MODEL.deivce = device
    cfg.OUTPUT_DIR = output_dir

    return cfg 

def on_image(image_path, predictor):
    im = cv2.imread(image_path)
    outputs = predictor(im)
    print(outputs)
    v = Visualizer(im[:,:,::-1], metadata={}, scale =1, instance_mode=ColorMode.SEGMENTATION)
    v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    plt.figure(figsize=(5,5))
    plt.imshow(v.get_image())
    plt.show()

# %%
## If doing instance segmentation:
config_file_path = "COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"
checkpoint_url = "COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"
output_dir = "./output"
num_classes = 5

device = "cuda"

train_dataset_name = "LP_train"
train_images_path = "train"
train_json_annot_path = "train/_annotations.coco.json"

test_dataset_name = "LP_valid"
test_images_path = "test"
test_json_annot_path = "test/_annotations.coco.json"

cfg_save_path = "IS_cfg.pickle"

register_coco_instances(name = train_dataset_name, metadata={}, json_file=train_json_annot_path, image_root=train_images_path)
register_coco_instances(name = test_dataset_name, metadata={}, json_file=test_json_annot_path, image_root=test_images_path)

# plot_samples(train_dataset_name)

cfg = get_train_cfg(config_file_path, checkpoint_url, train_dataset_name, test_dataset_name, num_classes, device, output_dir)\

with open(cfg_save_path, 'wb') as f:
    pickle.dump(cfg, f, protocol=pickle.HIGHEST_PROTOCOL)

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

# %%
trainer = DefaultTrainer(cfg)
trainer.resume_or_load(resume = True)

trainer.train()
# Out:
# [09/19 05:32:09 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=6, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=20, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 5, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# WARNING [09/19 05:32:09 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [09/19 05:32:09 d2.data.datasets.coco]: Loaded 234 images in COCO format from train/_annotations.coco.json
# [09/19 05:32:09 d2.data.build]: Removed 0 images with no usable annotations. 234 images left.
# [09/19 05:32:09 d2.data.build]: Distribution of instances among all 6 categories:
# |   category    | #instances   |   category    | #instances   |   category    | #instances   |
# |:-------------:|:-------------|:-------------:|:-------------|:-------------:|:-------------|
# |  pipe-layers  | 0            |    carcass    | 245          | external_po.. | 314          |
# | internal_fl.. | 286          | pressure_ar.. | 323          | tensile_arm.. | 335          |
# |               |              |               |              |               |              |
# |     total     | 1503         |               |              |               |              |
# [09/19 05:32:09 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [09/19 05:32:09 d2.data.build]: Using training sampler TrainingSampler
# [09/19 05:32:09 d2.data.common]: Serializing 234 elements to byte tensors and concatenating them all ...
# [09/19 05:32:09 d2.data.common]: Serialized dataset takes 1.04 MiB
# [09/19 05:32:10 d2.checkpoint.c2_model_loading]: Following weights matched with model:
# | Names in Model                                  | Names in Checkpoint                                                                                  | Shapes                                          |
# |:------------------------------------------------|:-----------------------------------------------------------------------------------------------------|:------------------------------------------------|
# | backbone.bottom_up.res2.0.conv1.*               | backbone.bottom_up.res2.0.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (64,) (64,) (64,) (64,) (64,64,1,1)             |
# | backbone.bottom_up.res2.0.conv2.*               | backbone.bottom_up.res2.0.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (64,) (64,) (64,) (64,) (64,64,3,3)             |
# | backbone.bottom_up.res2.0.conv3.*               | backbone.bottom_up.res2.0.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,64,1,1)        |
# | backbone.bottom_up.res2.0.shortcut.*            | backbone.bottom_up.res2.0.shortcut.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight} | (256,) (256,) (256,) (256,) (256,64,1,1)        |
# | backbone.bottom_up.res2.1.conv1.*               | backbone.bottom_up.res2.1.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (64,) (64,) (64,) (64,) (64,256,1,1)            |
# | backbone.bottom_up.res2.1.conv2.*               | backbone.bottom_up.res2.1.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (64,) (64,) (64,) (64,) (64,64,3,3)             |
# | backbone.bottom_up.res2.1.conv3.*               | backbone.bottom_up.res2.1.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,64,1,1)        |
# | backbone.bottom_up.res2.2.conv1.*               | backbone.bottom_up.res2.2.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (64,) (64,) (64,) (64,) (64,256,1,1)            |
# | backbone.bottom_up.res2.2.conv2.*               | backbone.bottom_up.res2.2.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (64,) (64,) (64,) (64,) (64,64,3,3)             |
# | backbone.bottom_up.res2.2.conv3.*               | backbone.bottom_up.res2.2.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,64,1,1)        |
# | backbone.bottom_up.res3.0.conv1.*               | backbone.bottom_up.res3.0.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (128,) (128,) (128,) (128,) (128,256,1,1)       |
# | backbone.bottom_up.res3.0.conv2.*               | backbone.bottom_up.res3.0.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (128,) (128,) (128,) (128,) (128,128,3,3)       |
# | backbone.bottom_up.res3.0.conv3.*               | backbone.bottom_up.res3.0.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,128,1,1)       |
# | backbone.bottom_up.res3.0.shortcut.*            | backbone.bottom_up.res3.0.shortcut.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight} | (512,) (512,) (512,) (512,) (512,256,1,1)       |
# | backbone.bottom_up.res3.1.conv1.*               | backbone.bottom_up.res3.1.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (128,) (128,) (128,) (128,) (128,512,1,1)       |
# | backbone.bottom_up.res3.1.conv2.*               | backbone.bottom_up.res3.1.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (128,) (128,) (128,) (128,) (128,128,3,3)       |
# | backbone.bottom_up.res3.1.conv3.*               | backbone.bottom_up.res3.1.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,128,1,1)       |
# | backbone.bottom_up.res3.2.conv1.*               | backbone.bottom_up.res3.2.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (128,) (128,) (128,) (128,) (128,512,1,1)       |
# | backbone.bottom_up.res3.2.conv2.*               | backbone.bottom_up.res3.2.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (128,) (128,) (128,) (128,) (128,128,3,3)       |
# | backbone.bottom_up.res3.2.conv3.*               | backbone.bottom_up.res3.2.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,128,1,1)       |
# | backbone.bottom_up.res3.3.conv1.*               | backbone.bottom_up.res3.3.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (128,) (128,) (128,) (128,) (128,512,1,1)       |
# | backbone.bottom_up.res3.3.conv2.*               | backbone.bottom_up.res3.3.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (128,) (128,) (128,) (128,) (128,128,3,3)       |
# | backbone.bottom_up.res3.3.conv3.*               | backbone.bottom_up.res3.3.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,128,1,1)       |
# | backbone.bottom_up.res4.0.conv1.*               | backbone.bottom_up.res4.0.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,512,1,1)       |
# | backbone.bottom_up.res4.0.conv2.*               | backbone.bottom_up.res4.0.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,256,3,3)       |
# | backbone.bottom_up.res4.0.conv3.*               | backbone.bottom_up.res4.0.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (1024,) (1024,) (1024,) (1024,) (1024,256,1,1)  |
# | backbone.bottom_up.res4.0.shortcut.*            | backbone.bottom_up.res4.0.shortcut.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight} | (1024,) (1024,) (1024,) (1024,) (1024,512,1,1)  |
# | backbone.bottom_up.res4.1.conv1.*               | backbone.bottom_up.res4.1.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,1024,1,1)      |
# | backbone.bottom_up.res4.1.conv2.*               | backbone.bottom_up.res4.1.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,256,3,3)       |
# | backbone.bottom_up.res4.1.conv3.*               | backbone.bottom_up.res4.1.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (1024,) (1024,) (1024,) (1024,) (1024,256,1,1)  |
# | backbone.bottom_up.res4.2.conv1.*               | backbone.bottom_up.res4.2.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,1024,1,1)      |
# | backbone.bottom_up.res4.2.conv2.*               | backbone.bottom_up.res4.2.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,256,3,3)       |
# | backbone.bottom_up.res4.2.conv3.*               | backbone.bottom_up.res4.2.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (1024,) (1024,) (1024,) (1024,) (1024,256,1,1)  |
# | backbone.bottom_up.res4.3.conv1.*               | backbone.bottom_up.res4.3.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,1024,1,1)      |
# | backbone.bottom_up.res4.3.conv2.*               | backbone.bottom_up.res4.3.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,256,3,3)       |
# | backbone.bottom_up.res4.3.conv3.*               | backbone.bottom_up.res4.3.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (1024,) (1024,) (1024,) (1024,) (1024,256,1,1)  |
# | backbone.bottom_up.res4.4.conv1.*               | backbone.bottom_up.res4.4.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,1024,1,1)      |
# | backbone.bottom_up.res4.4.conv2.*               | backbone.bottom_up.res4.4.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,256,3,3)       |
# | backbone.bottom_up.res4.4.conv3.*               | backbone.bottom_up.res4.4.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (1024,) (1024,) (1024,) (1024,) (1024,256,1,1)  |
# | backbone.bottom_up.res4.5.conv1.*               | backbone.bottom_up.res4.5.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,1024,1,1)      |
# | backbone.bottom_up.res4.5.conv2.*               | backbone.bottom_up.res4.5.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,256,3,3)       |
# | backbone.bottom_up.res4.5.conv3.*               | backbone.bottom_up.res4.5.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (1024,) (1024,) (1024,) (1024,) (1024,256,1,1)  |
# | backbone.bottom_up.res5.0.conv1.*               | backbone.bottom_up.res5.0.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,1024,1,1)      |
# | backbone.bottom_up.res5.0.conv2.*               | backbone.bottom_up.res5.0.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,512,3,3)       |
# | backbone.bottom_up.res5.0.conv3.*               | backbone.bottom_up.res5.0.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (2048,) (2048,) (2048,) (2048,) (2048,512,1,1)  |
# | backbone.bottom_up.res5.0.shortcut.*            | backbone.bottom_up.res5.0.shortcut.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight} | (2048,) (2048,) (2048,) (2048,) (2048,1024,1,1) |
# | backbone.bottom_up.res5.1.conv1.*               | backbone.bottom_up.res5.1.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,2048,1,1)      |
# | backbone.bottom_up.res5.1.conv2.*               | backbone.bottom_up.res5.1.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,512,3,3)       |
# | backbone.bottom_up.res5.1.conv3.*               | backbone.bottom_up.res5.1.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (2048,) (2048,) (2048,) (2048,) (2048,512,1,1)  |
# | backbone.bottom_up.res5.2.conv1.*               | backbone.bottom_up.res5.2.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,2048,1,1)      |
# | backbone.bottom_up.res5.2.conv2.*               | backbone.bottom_up.res5.2.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,512,3,3)       |
# | backbone.bottom_up.res5.2.conv3.*               | backbone.bottom_up.res5.2.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (2048,) (2048,) (2048,) (2048,) (2048,512,1,1)  |
# | backbone.bottom_up.stem.conv1.*                 | backbone.bottom_up.stem.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}      | (64,) (64,) (64,) (64,) (64,3,7,7)              |
# | backbone.fpn_lateral2.*                         | backbone.fpn_lateral2.{bias,weight}                                                                  | (256,) (256,256,1,1)                            |
# | backbone.fpn_lateral3.*                         | backbone.fpn_lateral3.{bias,weight}                                                                  | (256,) (256,512,1,1)                            |
# | backbone.fpn_lateral4.*                         | backbone.fpn_lateral4.{bias,weight}                                                                  | (256,) (256,1024,1,1)                           |
# | backbone.fpn_lateral5.*                         | backbone.fpn_lateral5.{bias,weight}                                                                  | (256,) (256,2048,1,1)                           |
# | backbone.fpn_output2.*                          | backbone.fpn_output2.{bias,weight}                                                                   | (256,) (256,256,3,3)                            |
# | backbone.fpn_output3.*                          | backbone.fpn_output3.{bias,weight}                                                                   | (256,) (256,256,3,3)                            |
# | backbone.fpn_output4.*                          | backbone.fpn_output4.{bias,weight}                                                                   | (256,) (256,256,3,3)                            |
# | backbone.fpn_output5.*                          | backbone.fpn_output5.{bias,weight}                                                                   | (256,) (256,256,3,3)                            |
# | proposal_generator.rpn_head.anchor_deltas.*     | proposal_generator.rpn_head.anchor_deltas.{bias,weight}                                              | (12,) (12,256,1,1)                              |
# | proposal_generator.rpn_head.conv.*              | proposal_generator.rpn_head.conv.{bias,weight}                                                       | (256,) (256,256,3,3)                            |
# | proposal_generator.rpn_head.objectness_logits.* | proposal_generator.rpn_head.objectness_logits.{bias,weight}                                          | (3,) (3,256,1,1)                                |
# | roi_heads.box_head.fc1.*                        | roi_heads.box_head.fc1.{bias,weight}                                                                 | (1024,) (1024,12544)                            |
# | roi_heads.box_head.fc2.*                        | roi_heads.box_head.fc2.{bias,weight}                                                                 | (1024,) (1024,1024)                             |
# | roi_heads.box_predictor.bbox_pred.*             | roi_heads.box_predictor.bbox_pred.{bias,weight}                                                      | (20,) (20,1024)                                 |
# | roi_heads.box_predictor.cls_score.*             | roi_heads.box_predictor.cls_score.{bias,weight}                                                      | (6,) (6,1024)                                   |
# | roi_heads.mask_head.deconv.*                    | roi_heads.mask_head.deconv.{bias,weight}                                                             | (256,) (256,256,2,2)                            |
# | roi_heads.mask_head.mask_fcn1.*                 | roi_heads.mask_head.mask_fcn1.{bias,weight}                                                          | (256,) (256,256,3,3)                            |
# | roi_heads.mask_head.mask_fcn2.*                 | roi_heads.mask_head.mask_fcn2.{bias,weight}                                                          | (256,) (256,256,3,3)                            |
# | roi_heads.mask_head.mask_fcn3.*                 | roi_heads.mask_head.mask_fcn3.{bias,weight}                                                          | (256,) (256,256,3,3)                            |
# | roi_heads.mask_head.mask_fcn4.*                 | roi_heads.mask_head.mask_fcn4.{bias,weight}                                                          | (256,) (256,256,3,3)                            |
# | roi_heads.mask_head.predictor.*                 | roi_heads.mask_head.predictor.{bias,weight}                                                          | (5,) (5,256,1,1)                                |
# [09/19 05:32:10 d2.engine.hooks]: Loading scheduler from state_dict ...
# [09/19 05:32:10 d2.engine.train_loop]: Starting training from iteration 2000
# d:\venv\lib\site-packages\torch\functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ..\aten\src\ATen\native\TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [09/19 05:32:45 d2.utils.events]:  eta: 3:56:50  iter: 2019  total_loss: 0.4494  loss_cls: 0.1049  loss_box_reg: 0.08401  loss_mask: 0.2481  loss_rpn_cls: 0.0006694  loss_rpn_loc: 0.01058  time: 1.5509  data_time: 0.0870  lr: 0.00025  max_mem: 3855M
# [09/19 05:33:04 d2.utils.events]:  eta: 3:05:11  iter: 2039  total_loss: 0.4275  loss_cls: 0.09861  loss_box_reg: 0.07769  loss_mask: 0.2288  loss_rpn_cls: 0.0007763  loss_rpn_loc: 0.01011  time: 1.2515  data_time: 0.0124  lr: 0.00025  max_mem: 3855M
# [09/19 05:33:23 d2.utils.events]:  eta: 1:33:49  iter: 2059  total_loss: 0.4386  loss_cls: 0.09588  loss_box_reg: 0.07568  loss_mask: 0.2352  loss_rpn_cls: 0.0007175  loss_rpn_loc: 0.01004  time: 1.1441  data_time: 0.0145  lr: 0.00025  max_mem: 3855M
# [09/19 05:33:42 d2.utils.events]:  eta: 1:25:58  iter: 2079  total_loss: 0.439  loss_cls: 0.105  loss_box_reg: 0.08237  loss_mask: 0.2392  loss_rpn_cls: 0.002165  loss_rpn_loc: 0.01022  time: 1.0895  data_time: 0.0139  lr: 0.00025  max_mem: 3855M
# [09/19 05:34:01 d2.utils.events]:  eta: 1:24:03  iter: 2099  total_loss: 0.4341  loss_cls: 0.09177  loss_box_reg: 0.08441  loss_mask: 0.2433  loss_rpn_cls: 0.000691  loss_rpn_loc: 0.009877  time: 1.0620  data_time: 0.0133  lr: 0.00025  max_mem: 3855M
# [09/19 05:34:20 d2.utils.events]:  eta: 1:23:28  iter: 2119  total_loss: 0.4171  loss_cls: 0.09153  loss_box_reg: 0.07016  loss_mask: 0.2309  loss_rpn_cls: 0.001355  loss_rpn_loc: 0.01014  time: 1.0392  data_time: 0.0134  lr: 0.00025  max_mem: 3855M
# [09/19 05:34:39 d2.utils.events]:  eta: 1:23:11  iter: 2139  total_loss: 0.4213  loss_cls: 0.09585  loss_box_reg: 0.08081  loss_mask: 0.23  loss_rpn_cls: 0.0007153  loss_rpn_loc: 0.01051  time: 1.0255  data_time: 0.0134  lr: 0.00025  max_mem: 3855M
# [09/19 05:34:57 d2.utils.events]:  eta: 1:22:58  iter: 2159  total_loss: 0.417  loss_cls: 0.09589  loss_box_reg: 0.08377  loss_mask: 0.2217  loss_rpn_cls: 0.002207  loss_rpn_loc: 0.008639  time: 1.0126  data_time: 0.0125  lr: 0.00025  max_mem: 3855M
# [09/19 05:35:16 d2.utils.events]:  eta: 1:22:50  iter: 2179  total_loss: 0.4393  loss_cls: 0.09939  loss_box_reg: 0.07923  loss_mask: 0.2231  loss_rpn_cls: 0.001315  loss_rpn_loc: 0.01042  time: 1.0040  data_time: 0.0131  lr: 0.00025  max_mem: 3855M
# [09/19 05:35:35 d2.utils.events]:  eta: 1:22:33  iter: 2199  total_loss: 0.3938  loss_cls: 0.09605  loss_box_reg: 0.07679  loss_mask: 0.2216  loss_rpn_cls: 0.000776  loss_rpn_loc: 0.008709  time: 0.9973  data_time: 0.0129  lr: 0.00025  max_mem: 3855M
# [09/19 05:35:53 d2.utils.events]:  eta: 1:22:09  iter: 2219  total_loss: 0.4029  loss_cls: 0.08839  loss_box_reg: 0.0757  loss_mask: 0.2269  loss_rpn_cls: 0.0006215  loss_rpn_loc: 0.008083  time: 0.9912  data_time: 0.0140  lr: 0.00025  max_mem: 3855M
# [09/19 05:36:09 d2.utils.events]:  eta: 1:22:02  iter: 2239  total_loss: 0.4081  loss_cls: 0.0975  loss_box_reg: 0.07717  loss_mask: 0.2155  loss_rpn_cls: 0.0007147  loss_rpn_loc: 0.0102  time: 0.9740  data_time: 0.0142  lr: 0.00025  max_mem: 3855M
# [09/19 05:36:27 d2.utils.events]:  eta: 1:21:54  iter: 2259  total_loss: 0.4435  loss_cls: 0.1021  loss_box_reg: 0.07613  loss_mask: 0.224  loss_rpn_cls: 0.0006479  loss_rpn_loc: 0.009309  time: 0.9691  data_time: 0.0133  lr: 0.00025  max_mem: 3855M
# [09/19 05:36:46 d2.utils.events]:  eta: 1:21:41  iter: 2279  total_loss: 0.4292  loss_cls: 0.1009  loss_box_reg: 0.07848  loss_mask: 0.2311  loss_rpn_cls: 0.000589  loss_rpn_loc: 0.01056  time: 0.9672  data_time: 0.0129  lr: 0.00025  max_mem: 3855M
# [09/19 05:37:06 d2.utils.events]:  eta: 1:21:23  iter: 2299  total_loss: 0.4191  loss_cls: 0.09385  loss_box_reg: 0.07295  loss_mask: 0.2342  loss_rpn_cls: 0.0003812  loss_rpn_loc: 0.01022  time: 0.9662  data_time: 0.0132  lr: 0.00025  max_mem: 3855M
# [09/19 05:37:24 d2.utils.events]:  eta: 1:21:09  iter: 2319  total_loss: 0.4596  loss_cls: 0.1072  loss_box_reg: 0.08889  loss_mask: 0.2515  loss_rpn_cls: 0.001862  loss_rpn_loc: 0.009084  time: 0.9643  data_time: 0.0130  lr: 0.00025  max_mem: 3855M
# [09/19 05:37:44 d2.utils.events]:  eta: 1:20:55  iter: 2339  total_loss: 0.3838  loss_cls: 0.08651  loss_box_reg: 0.06863  loss_mask: 0.2245  loss_rpn_cls: 0.0005166  loss_rpn_loc: 0.009932  time: 0.9641  data_time: 0.0122  lr: 0.00025  max_mem: 3855M
# [09/19 05:38:00 d2.utils.events]:  eta: 1:20:46  iter: 2359  total_loss: 0.4025  loss_cls: 0.09255  loss_box_reg: 0.07947  loss_mask: 0.2106  loss_rpn_cls: 0.00139  loss_rpn_loc: 0.01044  time: 0.9566  data_time: 0.0138  lr: 0.00025  max_mem: 3855M
# [09/19 05:38:20 d2.utils.events]:  eta: 1:20:34  iter: 2379  total_loss: 0.3941  loss_cls: 0.08941  loss_box_reg: 0.06929  loss_mask: 0.219  loss_rpn_cls: 0.001491  loss_rpn_loc: 0.00812  time: 0.9557  data_time: 0.0127  lr: 0.00025  max_mem: 3855M
# [09/19 05:38:36 d2.utils.events]:  eta: 1:20:23  iter: 2399  total_loss: 0.398  loss_cls: 0.09185  loss_box_reg: 0.06979  loss_mask: 0.2172  loss_rpn_cls: 0.0005448  loss_rpn_loc: 0.009681  time: 0.9495  data_time: 0.0132  lr: 0.00025  max_mem: 3855M
# [09/19 05:38:55 d2.utils.events]:  eta: 1:20:15  iter: 2419  total_loss: 0.3934  loss_cls: 0.09761  loss_box_reg: 0.07894  loss_mask: 0.2054  loss_rpn_cls: 0.0005035  loss_rpn_loc: 0.009389  time: 0.9478  data_time: 0.0133  lr: 0.00025  max_mem: 3855M
# [09/19 05:39:14 d2.utils.events]:  eta: 1:19:57  iter: 2439  total_loss: 0.3826  loss_cls: 0.08699  loss_box_reg: 0.06483  loss_mask: 0.2159  loss_rpn_cls: 0.000251  loss_rpn_loc: 0.008069  time: 0.9480  data_time: 0.0131  lr: 0.00025  max_mem: 3855M
# [09/19 05:39:33 d2.utils.events]:  eta: 1:19:43  iter: 2459  total_loss: 0.4327  loss_cls: 0.09554  loss_box_reg: 0.08152  loss_mask: 0.2279  loss_rpn_cls: 0.0009365  loss_rpn_loc: 0.009745  time: 0.9479  data_time: 0.0129  lr: 0.00025  max_mem: 3855M
# [09/19 05:39:52 d2.utils.events]:  eta: 1:19:31  iter: 2479  total_loss: 0.4218  loss_cls: 0.09802  loss_box_reg: 0.07119  loss_mask: 0.2135  loss_rpn_cls: 0.0002381  loss_rpn_loc: 0.009046  time: 0.9480  data_time: 0.0130  lr: 0.00025  max_mem: 4072M
# [09/19 05:40:10 d2.utils.events]:  eta: 1:19:22  iter: 2499  total_loss: 0.4118  loss_cls: 0.09468  loss_box_reg: 0.07718  loss_mask: 0.2206  loss_rpn_cls: 0.0006018  loss_rpn_loc: 0.01016  time: 0.9475  data_time: 0.0134  lr: 0.00025  max_mem: 4072M
# [09/19 05:40:29 d2.utils.events]:  eta: 1:19:10  iter: 2519  total_loss: 0.3812  loss_cls: 0.09375  loss_box_reg: 0.07234  loss_mask: 0.2047  loss_rpn_cls: 0.001175  loss_rpn_loc: 0.009276  time: 0.9477  data_time: 0.0137  lr: 0.00025  max_mem: 4072M
# [09/19 05:40:48 d2.utils.events]:  eta: 1:18:57  iter: 2539  total_loss: 0.3815  loss_cls: 0.08743  loss_box_reg: 0.07122  loss_mask: 0.2079  loss_rpn_cls: 0.0007169  loss_rpn_loc: 0.008489  time: 0.9474  data_time: 0.0143  lr: 0.00025  max_mem: 4072M
# [09/19 05:41:08 d2.utils.events]:  eta: 1:18:46  iter: 2559  total_loss: 0.3926  loss_cls: 0.09309  loss_box_reg: 0.07124  loss_mask: 0.2204  loss_rpn_cls: 0.0006156  loss_rpn_loc: 0.009509  time: 0.9478  data_time: 0.0135  lr: 0.00025  max_mem: 4072M
# [09/19 05:41:27 d2.utils.events]:  eta: 1:18:32  iter: 2579  total_loss: 0.3904  loss_cls: 0.09498  loss_box_reg: 0.07793  loss_mask: 0.2012  loss_rpn_cls: 0.001746  loss_rpn_loc: 0.009024  time: 0.9479  data_time: 0.0140  lr: 0.00025  max_mem: 4072M
# [09/19 05:41:41 d2.utils.events]:  eta: 1:18:23  iter: 2599  total_loss: 0.3846  loss_cls: 0.09186  loss_box_reg: 0.07531  loss_mask: 0.2051  loss_rpn_cls: 0.0006507  loss_rpn_loc: 0.009276  time: 0.9406  data_time: 0.0131  lr: 0.00025  max_mem: 4072M
# [09/19 05:41:53 d2.utils.events]:  eta: 1:18:03  iter: 2619  total_loss: 0.4008  loss_cls: 0.09229  loss_box_reg: 0.07669  loss_mask: 0.2309  loss_rpn_cls: 0.0008441  loss_rpn_loc: 0.009347  time: 0.9297  data_time: 0.0143  lr: 0.00025  max_mem: 4072M
# [09/19 05:42:05 d2.utils.events]:  eta: 1:17:44  iter: 2639  total_loss: 0.3715  loss_cls: 0.09085  loss_box_reg: 0.07543  loss_mask: 0.1967  loss_rpn_cls: 0.0003497  loss_rpn_loc: 0.009297  time: 0.9195  data_time: 0.0138  lr: 0.00025  max_mem: 4072M
# [09/19 05:42:18 d2.utils.events]:  eta: 1:17:25  iter: 2659  total_loss: 0.3862  loss_cls: 0.09323  loss_box_reg: 0.07368  loss_mask: 0.2067  loss_rpn_cls: 0.0002092  loss_rpn_loc: 0.008915  time: 0.9101  data_time: 0.0132  lr: 0.00025  max_mem: 4072M
# [09/19 05:42:30 d2.utils.events]:  eta: 1:17:07  iter: 2679  total_loss: 0.4063  loss_cls: 0.0871  loss_box_reg: 0.06801  loss_mask: 0.2135  loss_rpn_cls: 0.001264  loss_rpn_loc: 0.008224  time: 0.9011  data_time: 0.0128  lr: 0.00025  max_mem: 4072M
# [09/19 05:42:42 d2.utils.events]:  eta: 1:16:49  iter: 2699  total_loss: 0.4076  loss_cls: 0.09755  loss_box_reg: 0.07604  loss_mask: 0.2082  loss_rpn_cls: 0.0003496  loss_rpn_loc: 0.009859  time: 0.8924  data_time: 0.0135  lr: 0.00025  max_mem: 4072M
# [09/19 05:42:54 d2.utils.events]:  eta: 1:16:28  iter: 2719  total_loss: 0.4025  loss_cls: 0.09566  loss_box_reg: 0.07311  loss_mask: 0.2084  loss_rpn_cls: 0.001133  loss_rpn_loc: 0.009597  time: 0.8844  data_time: 0.0132  lr: 0.00025  max_mem: 4072M
# [09/19 05:43:06 d2.utils.events]:  eta: 1:16:07  iter: 2739  total_loss: 0.3598  loss_cls: 0.08724  loss_box_reg: 0.06697  loss_mask: 0.197  loss_rpn_cls: 0.0002445  loss_rpn_loc: 0.008331  time: 0.8764  data_time: 0.0127  lr: 0.00025  max_mem: 4072M
# [09/19 05:43:19 d2.utils.events]:  eta: 1:15:54  iter: 2759  total_loss: 0.3852  loss_cls: 0.096  loss_box_reg: 0.08217  loss_mask: 0.1987  loss_rpn_cls: 0.001143  loss_rpn_loc: 0.01009  time: 0.8699  data_time: 0.0130  lr: 0.00025  max_mem: 4072M
# [09/19 05:43:31 d2.utils.events]:  eta: 1:15:37  iter: 2779  total_loss: 0.4063  loss_cls: 0.09461  loss_box_reg: 0.07277  loss_mask: 0.2167  loss_rpn_cls: 0.0004848  loss_rpn_loc: 0.008923  time: 0.8632  data_time: 0.0133  lr: 0.00025  max_mem: 4072M
# [09/19 05:43:43 d2.utils.events]:  eta: 1:15:23  iter: 2799  total_loss: 0.4023  loss_cls: 0.09298  loss_box_reg: 0.07356  loss_mask: 0.2066  loss_rpn_cls: 0.0005007  loss_rpn_loc: 0.009077  time: 0.8568  data_time: 0.0128  lr: 0.00025  max_mem: 4072M
# [09/19 05:43:55 d2.utils.events]:  eta: 1:15:05  iter: 2819  total_loss: 0.3964  loss_cls: 0.09221  loss_box_reg: 0.07561  loss_mask: 0.2042  loss_rpn_cls: 0.0008092  loss_rpn_loc: 0.0107  time: 0.8509  data_time: 0.0119  lr: 0.00025  max_mem: 4072M
# [09/19 05:44:08 d2.utils.events]:  eta: 1:14:54  iter: 2839  total_loss: 0.3881  loss_cls: 0.09113  loss_box_reg: 0.07721  loss_mask: 0.2175  loss_rpn_cls: 0.0004529  loss_rpn_loc: 0.008692  time: 0.8454  data_time: 0.0127  lr: 0.00025  max_mem: 4072M
# [09/19 05:44:20 d2.utils.events]:  eta: 1:14:40  iter: 2859  total_loss: 0.3706  loss_cls: 0.08404  loss_box_reg: 0.06984  loss_mask: 0.2008  loss_rpn_cls: 0.0003684  loss_rpn_loc: 0.008665  time: 0.8398  data_time: 0.0133  lr: 0.00025  max_mem: 4072M
# [09/19 05:44:32 d2.utils.events]:  eta: 1:14:21  iter: 2879  total_loss: 0.3835  loss_cls: 0.08598  loss_box_reg: 0.06918  loss_mask: 0.1899  loss_rpn_cls: 0.0006658  loss_rpn_loc: 0.008157  time: 0.8344  data_time: 0.0138  lr: 0.00025  max_mem: 4072M
# [09/19 05:44:44 d2.utils.events]:  eta: 1:14:05  iter: 2899  total_loss: 0.3977  loss_cls: 0.08792  loss_box_reg: 0.06992  loss_mask: 0.2155  loss_rpn_cls: 0.001042  loss_rpn_loc: 0.009237  time: 0.8290  data_time: 0.0123  lr: 0.00025  max_mem: 4072M
# [09/19 05:44:56 d2.utils.events]:  eta: 1:13:49  iter: 2919  total_loss: 0.3775  loss_cls: 0.08732  loss_box_reg: 0.06993  loss_mask: 0.1974  loss_rpn_cls: 0.000274  loss_rpn_loc: 0.00921  time: 0.8240  data_time: 0.0132  lr: 0.00025  max_mem: 4072M
# [09/19 05:45:08 d2.utils.events]:  eta: 1:13:35  iter: 2939  total_loss: 0.4267  loss_cls: 0.09723  loss_box_reg: 0.08283  loss_mask: 0.2047  loss_rpn_cls: 0.0004305  loss_rpn_loc: 0.009864  time: 0.8196  data_time: 0.0134  lr: 0.00025  max_mem: 4072M
# [09/19 05:45:20 d2.utils.events]:  eta: 1:13:17  iter: 2959  total_loss: 0.3417  loss_cls: 0.08269  loss_box_reg: 0.06157  loss_mask: 0.1866  loss_rpn_cls: 0.0002199  loss_rpn_loc: 0.008673  time: 0.8150  data_time: 0.0138  lr: 0.00025  max_mem: 4072M
# [09/19 05:45:32 d2.utils.events]:  eta: 1:13:02  iter: 2979  total_loss: 0.3789  loss_cls: 0.09586  loss_box_reg: 0.0727  loss_mask: 0.2012  loss_rpn_cls: 0.0005221  loss_rpn_loc: 0.008291  time: 0.8106  data_time: 0.0114  lr: 0.00025  max_mem: 4072M
# [09/19 05:45:45 d2.utils.events]:  eta: 1:12:49  iter: 2999  total_loss: 0.3642  loss_cls: 0.09013  loss_box_reg: 0.07328  loss_mask: 0.1928  loss_rpn_cls: 0.0004139  loss_rpn_loc: 0.008471  time: 0.8067  data_time: 0.0135  lr: 0.00025  max_mem: 4072M
# [09/19 05:45:57 d2.utils.events]:  eta: 1:12:32  iter: 3019  total_loss: 0.3495  loss_cls: 0.09072  loss_box_reg: 0.06457  loss_mask: 0.1862  loss_rpn_cls: 0.000303  loss_rpn_loc: 0.008094  time: 0.8030  data_time: 0.0132  lr: 0.00025  max_mem: 4072M
# [09/19 05:46:10 d2.utils.events]:  eta: 1:12:18  iter: 3039  total_loss: 0.3768  loss_cls: 0.09253  loss_box_reg: 0.0747  loss_mask: 0.1922  loss_rpn_cls: 0.0004225  loss_rpn_loc: 0.009608  time: 0.7995  data_time: 0.0137  lr: 0.00025  max_mem: 4072M
# [09/19 05:46:22 d2.utils.events]:  eta: 1:12:05  iter: 3059  total_loss: 0.364  loss_cls: 0.09169  loss_box_reg: 0.0648  loss_mask: 0.1919  loss_rpn_cls: 0.0003602  loss_rpn_loc: 0.008133  time: 0.7959  data_time: 0.0121  lr: 0.00025  max_mem: 4072M
# [09/19 05:46:34 d2.utils.events]:  eta: 1:11:51  iter: 3079  total_loss: 0.381  loss_cls: 0.09383  loss_box_reg: 0.07982  loss_mask: 0.1887  loss_rpn_cls: 0.0004843  loss_rpn_loc: 0.008883  time: 0.7926  data_time: 0.0134  lr: 0.00025  max_mem: 4072M
# [09/19 05:46:46 d2.utils.events]:  eta: 1:11:38  iter: 3099  total_loss: 0.3556  loss_cls: 0.08403  loss_box_reg: 0.06407  loss_mask: 0.18  loss_rpn_cls: 0.000511  loss_rpn_loc: 0.007049  time: 0.7891  data_time: 0.0134  lr: 0.00025  max_mem: 4072M
# [09/19 05:46:59 d2.utils.events]:  eta: 1:11:25  iter: 3119  total_loss: 0.3643  loss_cls: 0.08885  loss_box_reg: 0.07023  loss_mask: 0.1709  loss_rpn_cls: 0.0001925  loss_rpn_loc: 0.008847  time: 0.7861  data_time: 0.0130  lr: 0.00025  max_mem: 4072M
# [09/19 05:47:11 d2.utils.events]:  eta: 1:11:09  iter: 3139  total_loss: 0.3763  loss_cls: 0.09147  loss_box_reg: 0.0707  loss_mask: 0.1934  loss_rpn_cls: 0.0003011  loss_rpn_loc: 0.009204  time: 0.7830  data_time: 0.0136  lr: 0.00025  max_mem: 4072M
# [09/19 05:47:23 d2.utils.events]:  eta: 1:10:54  iter: 3159  total_loss: 0.3698  loss_cls: 0.08642  loss_box_reg: 0.06584  loss_mask: 0.1921  loss_rpn_cls: 0.0002678  loss_rpn_loc: 0.008832  time: 0.7801  data_time: 0.0130  lr: 0.00025  max_mem: 4072M
# [09/19 05:47:36 d2.utils.events]:  eta: 1:10:36  iter: 3179  total_loss: 0.3636  loss_cls: 0.09502  loss_box_reg: 0.07202  loss_mask: 0.1757  loss_rpn_cls: 0.0004058  loss_rpn_loc: 0.009673  time: 0.7771  data_time: 0.0126  lr: 0.00025  max_mem: 4072M
# [09/19 05:47:48 d2.utils.events]:  eta: 1:10:21  iter: 3199  total_loss: 0.3575  loss_cls: 0.0858  loss_box_reg: 0.06741  loss_mask: 0.1948  loss_rpn_cls: 0.0003055  loss_rpn_loc: 0.00865  time: 0.7741  data_time: 0.0134  lr: 0.00025  max_mem: 4072M
# [09/19 05:48:00 d2.utils.events]:  eta: 1:10:06  iter: 3219  total_loss: 0.343  loss_cls: 0.09007  loss_box_reg: 0.06935  loss_mask: 0.1683  loss_rpn_cls: 0.0006929  loss_rpn_loc: 0.007751  time: 0.7713  data_time: 0.0125  lr: 0.00025  max_mem: 4072M
# [09/19 05:48:12 d2.utils.events]:  eta: 1:09:48  iter: 3239  total_loss: 0.3693  loss_cls: 0.08339  loss_box_reg: 0.06384  loss_mask: 0.1958  loss_rpn_cls: 0.0008402  loss_rpn_loc: 0.0098  time: 0.7687  data_time: 0.0143  lr: 0.00025  max_mem: 4072M
# [09/19 05:48:24 d2.utils.events]:  eta: 1:09:32  iter: 3259  total_loss: 0.3486  loss_cls: 0.08794  loss_box_reg: 0.06757  loss_mask: 0.1826  loss_rpn_cls: 0.0003133  loss_rpn_loc: 0.009016  time: 0.7662  data_time: 0.0137  lr: 0.00025  max_mem: 4072M
# [09/19 05:48:36 d2.utils.events]:  eta: 1:09:18  iter: 3279  total_loss: 0.3984  loss_cls: 0.1038  loss_box_reg: 0.08378  loss_mask: 0.1909  loss_rpn_cls: 0.0003525  loss_rpn_loc: 0.009822  time: 0.7637  data_time: 0.0130  lr: 0.00025  max_mem: 4072M
# [09/19 05:48:48 d2.utils.events]:  eta: 1:09:03  iter: 3299  total_loss: 0.3711  loss_cls: 0.08437  loss_box_reg: 0.06371  loss_mask: 0.208  loss_rpn_cls: 0.0002701  loss_rpn_loc: 0.006983  time: 0.7611  data_time: 0.0132  lr: 0.00025  max_mem: 4072M
# [09/19 05:49:01 d2.utils.events]:  eta: 1:08:50  iter: 3319  total_loss: 0.3806  loss_cls: 0.09395  loss_box_reg: 0.07166  loss_mask: 0.189  loss_rpn_cls: 0.0001656  loss_rpn_loc: 0.007623  time: 0.7589  data_time: 0.0132  lr: 0.00025  max_mem: 4072M
# ...
# [09/19 06:44:05 d2.utils.events]:  eta: 0:09:53  iter: 8879  total_loss: 0.2309  loss_cls: 0.06652  loss_box_reg: 0.0439  loss_mask: 0.1123  loss_rpn_cls: 6.419e-05  loss_rpn_loc: 0.005793  time: 0.6234  data_time: 0.0123  lr: 0.00025  max_mem: 4072M
# [09/19 06:44:16 d2.utils.events]:  eta: 0:09:42  iter: 8899  total_loss: 0.2345  loss_cls: 0.06425  loss_box_reg: 0.04823  loss_mask: 0.1147  loss_rpn_cls: 0.0001225  loss_rpn_loc: 0.008248  time: 0.6231  data_time: 0.0119  lr: 0.00025  max_mem: 4072M
# [09/19 06:44:26 d2.utils.events]:  eta: 0:09:31  iter: 8919  total_loss: 0.2258  loss_cls: 0.06152  loss_box_reg: 0.04263  loss_mask: 0.1099  loss_rpn_cls: 4.081e-05  loss_rpn_loc: 0.007658  time: 0.6228  data_time: 0.0125  lr: 0.00025  max_mem: 4072M
# [09/19 06:44:37 d2.utils.events]:  eta: 0:09:21  iter: 8939  total_loss: 0.2387  loss_cls: 0.07039  loss_box_reg: 0.05049  loss_mask: 0.1105  loss_rpn_cls: 8.715e-05  loss_rpn_loc: 0.0083  time: 0.6225  data_time: 0.0125  lr: 0.00025  max_mem: 4072M
# [09/19 06:44:48 d2.utils.events]:  eta: 0:09:10  iter: 8959  total_loss: 0.2227  loss_cls: 0.06113  loss_box_reg: 0.04498  loss_mask: 0.1062  loss_rpn_cls: 3.808e-05  loss_rpn_loc: 0.00732  time: 0.6222  data_time: 0.0126  lr: 0.00025  max_mem: 4072M
# [09/19 06:44:58 d2.utils.events]:  eta: 0:09:00  iter: 8979  total_loss: 0.239  loss_cls: 0.06519  loss_box_reg: 0.04632  loss_mask: 0.1154  loss_rpn_cls: 2.808e-05  loss_rpn_loc: 0.00709  time: 0.6219  data_time: 0.0120  lr: 0.00025  max_mem: 4072M
# [09/19 06:45:09 d2.utils.events]:  eta: 0:08:49  iter: 8999  total_loss: 0.2466  loss_cls: 0.06937  loss_box_reg: 0.05001  loss_mask: 0.1105  loss_rpn_cls: 6.481e-05  loss_rpn_loc: 0.007448  time: 0.6217  data_time: 0.0125  lr: 0.00025  max_mem: 4072M
# [09/19 06:45:19 d2.utils.events]:  eta: 0:08:39  iter: 9019  total_loss: 0.2281  loss_cls: 0.06454  loss_box_reg: 0.04603  loss_mask: 0.109  loss_rpn_cls: 2.234e-05  loss_rpn_loc: 0.007703  time: 0.6214  data_time: 0.0139  lr: 0.00025  max_mem: 4072M
# [09/19 06:45:30 d2.utils.events]:  eta: 0:08:28  iter: 9039  total_loss: 0.2274  loss_cls: 0.062  loss_box_reg: 0.04603  loss_mask: 0.1067  loss_rpn_cls: 0.0001071  loss_rpn_loc: 0.007237  time: 0.6211  data_time: 0.0133  lr: 0.00025  max_mem: 4072M
# [09/19 06:45:40 d2.utils.events]:  eta: 0:08:18  iter: 9059  total_loss: 0.2383  loss_cls: 0.07273  loss_box_reg: 0.04928  loss_mask: 0.1115  loss_rpn_cls: 4.742e-05  loss_rpn_loc: 0.006017  time: 0.6208  data_time: 0.0126  lr: 0.00025  max_mem: 4072M
# [09/19 06:45:51 d2.utils.events]:  eta: 0:08:07  iter: 9079  total_loss: 0.2343  loss_cls: 0.06463  loss_box_reg: 0.0485  loss_mask: 0.1097  loss_rpn_cls: 3.608e-05  loss_rpn_loc: 0.007496  time: 0.6206  data_time: 0.0128  lr: 0.00025  max_mem: 4072M
# [09/19 06:46:01 d2.utils.events]:  eta: 0:07:56  iter: 9099  total_loss: 0.2216  loss_cls: 0.06228  loss_box_reg: 0.04276  loss_mask: 0.1116  loss_rpn_cls: 5.671e-05  loss_rpn_loc: 0.006425  time: 0.6203  data_time: 0.0123  lr: 0.00025  max_mem: 4072M
# [09/19 06:46:12 d2.utils.events]:  eta: 0:07:46  iter: 9119  total_loss: 0.2403  loss_cls: 0.06547  loss_box_reg: 0.0496  loss_mask: 0.1137  loss_rpn_cls: 7.623e-05  loss_rpn_loc: 0.007285  time: 0.6200  data_time: 0.0117  lr: 0.00025  max_mem: 4072M
# [09/19 06:46:22 d2.utils.events]:  eta: 0:07:35  iter: 9139  total_loss: 0.2315  loss_cls: 0.06655  loss_box_reg: 0.04669  loss_mask: 0.1133  loss_rpn_cls: 4.537e-05  loss_rpn_loc: 0.008492  time: 0.6197  data_time: 0.0134  lr: 0.00025  max_mem: 4072M
# [09/19 06:46:32 d2.utils.events]:  eta: 0:07:25  iter: 9159  total_loss: 0.2246  loss_cls: 0.06476  loss_box_reg: 0.04653  loss_mask: 0.112  loss_rpn_cls: 6.72e-05  loss_rpn_loc: 0.007678  time: 0.6194  data_time: 0.0120  lr: 0.00025  max_mem: 4072M
# [09/19 06:46:43 d2.utils.events]:  eta: 0:07:14  iter: 9179  total_loss: 0.2306  loss_cls: 0.06828  loss_box_reg: 0.04402  loss_mask: 0.1044  loss_rpn_cls: 9.194e-05  loss_rpn_loc: 0.005914  time: 0.6191  data_time: 0.0130  lr: 0.00025  max_mem: 4072M
# [09/19 06:46:53 d2.utils.events]:  eta: 0:07:03  iter: 9199  total_loss: 0.2476  loss_cls: 0.06684  loss_box_reg: 0.05125  loss_mask: 0.114  loss_rpn_cls: 5.093e-05  loss_rpn_loc: 0.008261  time: 0.6188  data_time: 0.0122  lr: 0.00025  max_mem: 4072M
# [09/19 06:47:04 d2.utils.events]:  eta: 0:06:52  iter: 9219  total_loss: 0.2269  loss_cls: 0.0622  loss_box_reg: 0.04569  loss_mask: 0.1094  loss_rpn_cls: 8.092e-05  loss_rpn_loc: 0.007598  time: 0.6186  data_time: 0.0126  lr: 0.00025  max_mem: 4072M
# [09/19 06:47:14 d2.utils.events]:  eta: 0:06:42  iter: 9239  total_loss: 0.2272  loss_cls: 0.06625  loss_box_reg: 0.0486  loss_mask: 0.1086  loss_rpn_cls: 5.944e-05  loss_rpn_loc: 0.008113  time: 0.6183  data_time: 0.0128  lr: 0.00025  max_mem: 4072M
# [09/19 06:47:25 d2.utils.events]:  eta: 0:06:31  iter: 9259  total_loss: 0.2293  loss_cls: 0.06296  loss_box_reg: 0.04494  loss_mask: 0.1116  loss_rpn_cls: 4.866e-05  loss_rpn_loc: 0.006746  time: 0.6181  data_time: 0.0120  lr: 0.00025  max_mem: 4072M
# [09/19 06:47:35 d2.utils.events]:  eta: 0:06:21  iter: 9279  total_loss: 0.2441  loss_cls: 0.06869  loss_box_reg: 0.05236  loss_mask: 0.1087  loss_rpn_cls: 0.0001197  loss_rpn_loc: 0.00786  time: 0.6178  data_time: 0.0130  lr: 0.00025  max_mem: 4072M
# [09/19 06:47:46 d2.utils.events]:  eta: 0:06:10  iter: 9299  total_loss: 0.2312  loss_cls: 0.06556  loss_box_reg: 0.04626  loss_mask: 0.1102  loss_rpn_cls: 6.562e-05  loss_rpn_loc: 0.00702  time: 0.6176  data_time: 0.0131  lr: 0.00025  max_mem: 4072M
# [09/19 06:47:57 d2.utils.events]:  eta: 0:06:00  iter: 9319  total_loss: 0.2295  loss_cls: 0.06823  loss_box_reg: 0.04712  loss_mask: 0.1075  loss_rpn_cls: 3.567e-05  loss_rpn_loc: 0.006565  time: 0.6173  data_time: 0.0129  lr: 0.00025  max_mem: 4072M
# [09/19 06:48:07 d2.utils.events]:  eta: 0:05:49  iter: 9339  total_loss: 0.2298  loss_cls: 0.06453  loss_box_reg: 0.04715  loss_mask: 0.1136  loss_rpn_cls: 0.0001295  loss_rpn_loc: 0.007846  time: 0.6171  data_time: 0.0121  lr: 0.00025  max_mem: 4072M
# [09/19 06:48:18 d2.utils.events]:  eta: 0:05:38  iter: 9359  total_loss: 0.2189  loss_cls: 0.06285  loss_box_reg: 0.04121  loss_mask: 0.1092  loss_rpn_cls: 4.549e-05  loss_rpn_loc: 0.007324  time: 0.6168  data_time: 0.0127  lr: 0.00025  max_mem: 4072M
# [09/19 06:48:28 d2.utils.events]:  eta: 0:05:28  iter: 9379  total_loss: 0.2169  loss_cls: 0.06312  loss_box_reg: 0.04116  loss_mask: 0.1025  loss_rpn_cls: 5.581e-05  loss_rpn_loc: 0.006431  time: 0.6165  data_time: 0.0121  lr: 0.00025  max_mem: 4072M
# [09/19 06:48:39 d2.utils.events]:  eta: 0:05:17  iter: 9399  total_loss: 0.2398  loss_cls: 0.0665  loss_box_reg: 0.05015  loss_mask: 0.1208  loss_rpn_cls: 0.0001306  loss_rpn_loc: 0.008211  time: 0.6163  data_time: 0.0122  lr: 0.00025  max_mem: 4072M
# [09/19 06:48:49 d2.utils.events]:  eta: 0:05:07  iter: 9419  total_loss: 0.2307  loss_cls: 0.06507  loss_box_reg: 0.04959  loss_mask: 0.111  loss_rpn_cls: 9.862e-05  loss_rpn_loc: 0.006518  time: 0.6160  data_time: 0.0122  lr: 0.00025  max_mem: 4072M
# [09/19 06:49:00 d2.utils.events]:  eta: 0:04:56  iter: 9439  total_loss: 0.2285  loss_cls: 0.06553  loss_box_reg: 0.04545  loss_mask: 0.1039  loss_rpn_cls: 2.893e-05  loss_rpn_loc: 0.007466  time: 0.6158  data_time: 0.0131  lr: 0.00025  max_mem: 4072M
# [09/19 06:49:10 d2.utils.events]:  eta: 0:04:46  iter: 9459  total_loss: 0.2343  loss_cls: 0.06759  loss_box_reg: 0.04774  loss_mask: 0.112  loss_rpn_cls: 3.783e-05  loss_rpn_loc: 0.008636  time: 0.6156  data_time: 0.0124  lr: 0.00025  max_mem: 4072M
# [09/19 06:49:21 d2.utils.events]:  eta: 0:04:35  iter: 9479  total_loss: 0.2289  loss_cls: 0.06528  loss_box_reg: 0.04501  loss_mask: 0.1104  loss_rpn_cls: 3.737e-05  loss_rpn_loc: 0.006159  time: 0.6153  data_time: 0.0126  lr: 0.00025  max_mem: 4072M
# [09/19 06:49:31 d2.utils.events]:  eta: 0:04:24  iter: 9499  total_loss: 0.2164  loss_cls: 0.06096  loss_box_reg: 0.0457  loss_mask: 0.1019  loss_rpn_cls: 0.0001466  loss_rpn_loc: 0.006101  time: 0.6150  data_time: 0.0127  lr: 0.00025  max_mem: 4072M
# [09/19 06:49:42 d2.utils.events]:  eta: 0:04:14  iter: 9519  total_loss: 0.2291  loss_cls: 0.06672  loss_box_reg: 0.04709  loss_mask: 0.1076  loss_rpn_cls: 2.461e-05  loss_rpn_loc: 0.007223  time: 0.6148  data_time: 0.0134  lr: 0.00025  max_mem: 4072M
# [09/19 06:49:52 d2.utils.events]:  eta: 0:04:04  iter: 9539  total_loss: 0.2379  loss_cls: 0.06814  loss_box_reg: 0.04667  loss_mask: 0.1102  loss_rpn_cls: 3.914e-05  loss_rpn_loc: 0.006783  time: 0.6146  data_time: 0.0125  lr: 0.00025  max_mem: 4072M
# [09/19 06:50:03 d2.utils.events]:  eta: 0:03:53  iter: 9559  total_loss: 0.2347  loss_cls: 0.06442  loss_box_reg: 0.04674  loss_mask: 0.1071  loss_rpn_cls: 8.443e-05  loss_rpn_loc: 0.008021  time: 0.6143  data_time: 0.0125  lr: 0.00025  max_mem: 4072M
# [09/19 06:50:13 d2.utils.events]:  eta: 0:03:42  iter: 9579  total_loss: 0.2372  loss_cls: 0.06758  loss_box_reg: 0.04783  loss_mask: 0.1075  loss_rpn_cls: 6.345e-05  loss_rpn_loc: 0.006908  time: 0.6141  data_time: 0.0127  lr: 0.00025  max_mem: 4072M
# [09/19 06:50:24 d2.utils.events]:  eta: 0:03:32  iter: 9599  total_loss: 0.2172  loss_cls: 0.06239  loss_box_reg: 0.04302  loss_mask: 0.1025  loss_rpn_cls: 0.0001144  loss_rpn_loc: 0.007293  time: 0.6139  data_time: 0.0121  lr: 0.00025  max_mem: 4072M
# [09/19 06:50:35 d2.utils.events]:  eta: 0:03:21  iter: 9619  total_loss: 0.2374  loss_cls: 0.0712  loss_box_reg: 0.04906  loss_mask: 0.1095  loss_rpn_cls: 1.08e-05  loss_rpn_loc: 0.006765  time: 0.6136  data_time: 0.0129  lr: 0.00025  max_mem: 4072M
# [09/19 06:50:45 d2.utils.events]:  eta: 0:03:10  iter: 9639  total_loss: 0.213  loss_cls: 0.05918  loss_box_reg: 0.04271  loss_mask: 0.1086  loss_rpn_cls: 0.0001125  loss_rpn_loc: 0.007399  time: 0.6134  data_time: 0.0132  lr: 0.00025  max_mem: 4072M
# [09/19 06:50:56 d2.utils.events]:  eta: 0:03:00  iter: 9659  total_loss: 0.2277  loss_cls: 0.06512  loss_box_reg: 0.04858  loss_mask: 0.106  loss_rpn_cls: 0.0001347  loss_rpn_loc: 0.00656  time: 0.6132  data_time: 0.0128  lr: 0.00025  max_mem: 4072M
# [09/19 06:51:06 d2.utils.events]:  eta: 0:02:49  iter: 9679  total_loss: 0.2261  loss_cls: 0.06336  loss_box_reg: 0.04484  loss_mask: 0.1096  loss_rpn_cls: 3.712e-05  loss_rpn_loc: 0.006559  time: 0.6130  data_time: 0.0138  lr: 0.00025  max_mem: 4072M
# [09/19 06:51:17 d2.utils.events]:  eta: 0:02:39  iter: 9699  total_loss: 0.2363  loss_cls: 0.06937  loss_box_reg: 0.05086  loss_mask: 0.1095  loss_rpn_cls: 6.085e-05  loss_rpn_loc: 0.009109  time: 0.6127  data_time: 0.0129  lr: 0.00025  max_mem: 4072M
# [09/19 06:51:27 d2.utils.events]:  eta: 0:02:28  iter: 9719  total_loss: 0.2222  loss_cls: 0.06287  loss_box_reg: 0.04451  loss_mask: 0.1047  loss_rpn_cls: 2.859e-05  loss_rpn_loc: 0.006352  time: 0.6125  data_time: 0.0128  lr: 0.00025  max_mem: 4072M
# [09/19 06:51:38 d2.utils.events]:  eta: 0:02:17  iter: 9739  total_loss: 0.2321  loss_cls: 0.06524  loss_box_reg: 0.04765  loss_mask: 0.1042  loss_rpn_cls: 7.73e-05  loss_rpn_loc: 0.007134  time: 0.6123  data_time: 0.0129  lr: 0.00025  max_mem: 4072M
# [09/19 06:51:48 d2.utils.events]:  eta: 0:02:07  iter: 9759  total_loss: 0.2148  loss_cls: 0.06167  loss_box_reg: 0.04748  loss_mask: 0.1011  loss_rpn_cls: 4.181e-05  loss_rpn_loc: 0.007169  time: 0.6120  data_time: 0.0123  lr: 0.00025  max_mem: 4072M
# [09/19 06:51:59 d2.utils.events]:  eta: 0:01:56  iter: 9779  total_loss: 0.2219  loss_cls: 0.06263  loss_box_reg: 0.04375  loss_mask: 0.113  loss_rpn_cls: 7.877e-05  loss_rpn_loc: 0.007339  time: 0.6118  data_time: 0.0128  lr: 0.00025  max_mem: 4072M
# [09/19 06:52:09 d2.utils.events]:  eta: 0:01:45  iter: 9799  total_loss: 0.2262  loss_cls: 0.06547  loss_box_reg: 0.0479  loss_mask: 0.1061  loss_rpn_cls: 5.168e-05  loss_rpn_loc: 0.006903  time: 0.6116  data_time: 0.0126  lr: 0.00025  max_mem: 4072M
# [09/19 06:52:20 d2.utils.events]:  eta: 0:01:35  iter: 9819  total_loss: 0.2314  loss_cls: 0.06776  loss_box_reg: 0.04855  loss_mask: 0.1088  loss_rpn_cls: 5.507e-05  loss_rpn_loc: 0.007388  time: 0.6113  data_time: 0.0131  lr: 0.00025  max_mem: 4072M
# [09/19 06:52:31 d2.utils.events]:  eta: 0:01:24  iter: 9839  total_loss: 0.2225  loss_cls: 0.06736  loss_box_reg: 0.04673  loss_mask: 0.1016  loss_rpn_cls: 4.617e-05  loss_rpn_loc: 0.006862  time: 0.6111  data_time: 0.0116  lr: 0.00025  max_mem: 4072M
# [09/19 06:52:41 d2.utils.events]:  eta: 0:01:14  iter: 9859  total_loss: 0.2268  loss_cls: 0.05939  loss_box_reg: 0.04588  loss_mask: 0.1079  loss_rpn_cls: 4.085e-05  loss_rpn_loc: 0.007138  time: 0.6109  data_time: 0.0133  lr: 0.00025  max_mem: 4072M
# [09/19 06:52:51 d2.utils.events]:  eta: 0:01:03  iter: 9879  total_loss: 0.2315  loss_cls: 0.06818  loss_box_reg: 0.05082  loss_mask: 0.1093  loss_rpn_cls: 7.354e-05  loss_rpn_loc: 0.008419  time: 0.6107  data_time: 0.0129  lr: 0.00025  max_mem: 4072M
# [09/19 06:53:02 d2.utils.events]:  eta: 0:00:52  iter: 9899  total_loss: 0.2192  loss_cls: 0.06246  loss_box_reg: 0.04383  loss_mask: 0.1031  loss_rpn_cls: 5.942e-05  loss_rpn_loc: 0.007217  time: 0.6104  data_time: 0.0126  lr: 0.00025  max_mem: 4072M
# [09/19 06:53:12 d2.utils.events]:  eta: 0:00:42  iter: 9919  total_loss: 0.2354  loss_cls: 0.06645  loss_box_reg: 0.04787  loss_mask: 0.1094  loss_rpn_cls: 5.695e-05  loss_rpn_loc: 0.007506  time: 0.6102  data_time: 0.0130  lr: 0.00025  max_mem: 4072M
# [09/19 06:53:23 d2.utils.events]:  eta: 0:00:31  iter: 9939  total_loss: 0.2297  loss_cls: 0.06589  loss_box_reg: 0.04928  loss_mask: 0.1094  loss_rpn_cls: 6.692e-05  loss_rpn_loc: 0.006856  time: 0.6100  data_time: 0.0125  lr: 0.00025  max_mem: 4072M
# [09/19 06:53:33 d2.utils.events]:  eta: 0:00:21  iter: 9959  total_loss: 0.223  loss_cls: 0.06383  loss_box_reg: 0.045  loss_mask: 0.1096  loss_rpn_cls: 3.763e-05  loss_rpn_loc: 0.006936  time: 0.6098  data_time: 0.0126  lr: 0.00025  max_mem: 4072M
# [09/19 06:53:44 d2.utils.events]:  eta: 0:00:10  iter: 9979  total_loss: 0.2295  loss_cls: 0.06334  loss_box_reg: 0.04848  loss_mask: 0.1075  loss_rpn_cls: 0.0001744  loss_rpn_loc: 0.007438  time: 0.6096  data_time: 0.0120  lr: 0.00025  max_mem: 4072M
# [09/19 06:53:57 d2.utils.events]:  eta: 0:00:00  iter: 9999  total_loss: 0.2197  loss_cls: 0.06274  loss_box_reg: 0.04546  loss_mask: 0.1052  loss_rpn_cls: 9.191e-05  loss_rpn_loc: 0.006774  time: 0.6093  data_time: 0.0125  lr: 0.00025  max_mem: 4072M
# [09/19 06:53:58 d2.engine.hooks]: Overall training speed: 7998 iterations in 1:21:13 (0.6093 s / it)
# [09/19 06:53:58 d2.engine.hooks]: Total training time: 1:21:39 (0:00:25 on hooks)
# WARNING [09/19 06:53:58 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [09/19 06:53:58 d2.data.datasets.coco]: Loaded 1 images in COCO format from test/_annotations.coco.json
# [09/19 06:53:58 d2.data.build]: Distribution of instances among all 6 categories:
# |   category    | #instances   |   category    | #instances   |   category    | #instances   |
# |:-------------:|:-------------|:-------------:|:-------------|:-------------:|:-------------|
# |  pipe-layers  | 0            |    carcass    | 1            | external_po.. | 1            |
# | internal_fl.. | 2            | pressure_ar.. | 1            | tensile_arm.. | 1            |
# |               |              |               |              |               |              |
# |     total     | 6            |               |              |               |              |
# [09/19 06:53:58 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [09/19 06:53:58 d2.data.common]: Serializing 1 elements to byte tensors and concatenating them all ...
# [09/19 06:53:58 d2.data.common]: Serialized dataset takes 0.00 MiB
# WARNING [09/19 06:53:58 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.

# %%
cfg_save_path = "IS_cfg.pickle"
with open(cfg_save_path, 'rb') as f:
    cfg = pickle.load(f)

cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.4

predictor = DefaultPredictor(cfg)

def test_output(dataset_name, n=1):
    dataset_custom = DatasetCatalog.get(dataset_name)
    dataset_custom_metadata = MetadataCatalog.get(dataset_name)

    for s in random.sample(dataset_custom, n):
        on_image(s["file_name"], predictor)

# test_output(test_dataset_name, 5)
image_path = "1.jpg"
im = cv2.imread(image_path)
outputs = predictor(im)
pred_img = np.zeros(im.shape, dtype = np.uint8)
labels = outputs["instances"].pred_classes.cpu().numpy()
masks = outputs["instances"].pred_masks.cpu().numpy()

label_map = {
    1: (255, 0, 0),
    2: (0, 255, 0),
    3: (0, 0, 255),
    4: (255, 255, 0),
    5: (0, 255, 255)
}

for i in range(masks.shape[0]):
    for w in range(masks[i].shape[0]):
        for j in range(masks[i].shape[1]):
            if masks[i][w][j] != False:
                pred_img[w][j] = label_map[labels[i]]

cv2.imwrite("out.png", pred_img)
# Out:
# True
